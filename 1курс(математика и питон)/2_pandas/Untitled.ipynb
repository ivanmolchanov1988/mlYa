# %%
import pandas as pd

# %%
# !more dataset.tsv
# Out:
# Name    Birth   City    Position
# Р�РІР°РЅРѕРІ Рђ.Рђ.    22.03.1980      РњРѕСЃРєРІР°
# РЎРѕСЂРѕРєРёРЅ Р�.Р’.  07.08.1965      Р’РѕР»РіРѕРіСЂР°Рґ      РёРЅР¶РµРЅРµСЂ
# Р‘РµР»РѕРІ Рњ.Рњ.        13.02.1980      Р РѕСЃС‚РѕРІ    РјРµРЅРµРґР¶РµСЂ
# РњРµР»СЊРЅРёРєРѕРІР° Р”.РЎ.    15.04.1985      Р РѕСЃС‚РѕРІ
# Р С‹Р±РёРЅР° Р•.Рџ.    19.11.1985      РњРѕСЃРєРІР°    РёРЅР¶РµРЅРµСЂ
# РљРѕСЃС‚СЂРѕРІ РЎ.Рћ.    31.05.1985      РњРѕСЃРєРІР°    СЃС‚Р°Р¶РµСЂ

# %%
frame = pd.DataFrame({'numbers':range(10), 'chars':['a']*10})

# %%
frame
# Out:
#    numbers chars
# 0        0     a
# 1        1     a
# 2        2     a
# 3        3     a
# 4        4     a
# 5        5     a
# 6        6     a
# 7        7     a
# 8        8     a
# 9        9     a

# %%
frame = pd.read_csv('dataset.tsv', header=0, sep='\t')

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер

# %%
frame.columns
# Out:
# Index(['Name', 'Birth', 'City', 'Position'], dtype='object')

# %%
frame.shape
# Out:
# (6, 4)

# %%
new_line = {'Name':'Петров', 'Birth':'15.04.1988', 'City':'Stavropol', 'Position':'инженер'}

# %%
frame.append(new_line, ignore_index=True)
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6           Петров  15.04.1988  Stavropol   инженер

# %%
frame = frame.append(new_line, ignore_index=True)

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6           Петров  15.04.1988  Stavropol   инженер

# %%
frame['IsStudent'] = [False]*5 + [True]*2

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True
# 6           Петров  15.04.1988  Stavropol   инженер       True

# %%
frame.drop(5, axis=0)
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False
# 6           Петров  15.04.1988  Stavropol   инженер       True

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True
# 6           Петров  15.04.1988  Stavropol   инженер       True

# %%
frame = frame.drop([6], axis=0)

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False

# %%
frame.to_csv('update_dataset.csv', sep=';', header=True, index=False)

# %%
# !more update_dataset.csv
# Out:
# Name;Birth;City;Position;IsStudent
# Р�РІР°РЅРѕРІ Рђ.Рђ.;22.03.1980;РњРѕСЃРєРІР°;;False
# РЎРѕСЂРѕРєРёРЅ Р�.Р’.;07.08.1965;Р’РѕР»РіРѕРіСЂР°Рґ;РёРЅР¶РµРЅРµСЂ;False
# Р‘РµР»РѕРІ Рњ.Рњ.;13.02.1980;Р РѕСЃС‚РѕРІ;РјРµРЅРµРґР¶РµСЂ;False
# РњРµР»СЊРЅРёРєРѕРІР° Р”.РЎ.;15.04.1985;Р РѕСЃС‚РѕРІ;;False
# Р С‹Р±РёРЅР° Р•.Рџ.;19.11.1985;РњРѕСЃРєРІР°;РёРЅР¶РµРЅРµСЂ;False

# %%
import codecs 
f = codecs.open('update_dataset.csv', 'r', 'utf-8') 
u = f.read()
print(u)
# Out:
# Name;Birth;City;Position;IsStudent
# Иванов А.А.;22.03.1980;Москва;;False
# Сорокин И.В.;07.08.1965;Волгоград;инженер;False
# Белов М.М.;13.02.1980;Ростов;менеджер;False
# Мельникова Д.С.;15.04.1985;Ростов;;False
# Рыбина Е.П.;19.11.1985;Москва;инженер;False

# %% [markdown]
# # pandas 2

# %%
frame = pd.read_csv('dataset.tsv', header=0, sep='\t'
# Out:
#   File "<ipython-input-153-b4882f905bda>", line 1
#     frame = pd.read_csv('dataset.tsv', header=0, sep='\t'
#                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False

# %%
frame.dtypes
# Out:
# Name         object
# Birth        object
# City         object
# Position     object
# IsStudent      bool
# dtype: object

# %%
frame.Birth = frame.Birth.apply(pd.to_datetime)

# %%
frame.dtypes
# Out:
# Name                 object
# Birth        datetime64[ns]
# City                 object
# Position             object
# IsStudent              bool
# dtype: object

# %%
frame.Position.fillna('Директор', inplace=True)
frame
# Out:
#               Name      Birth       City  Position  IsStudent
# 0      Иванов А.А. 1980-03-22     Москва  Директор      False
# 1     Сорокин И.В. 1965-07-08  Волгоград   инженер      False
# 2       Белов М.М. 1980-02-13     Ростов  менеджер      False
# 3  Мельникова Д.С. 1985-04-15     Ростов  Директор      False
# 4      Рыбина Е.П. 1985-11-19     Москва   инженер      False

# %%
frame.ix[[0,1,3],['Name','City']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#               Name       City
# 0      Иванов А.А.     Москва
# 1     Сорокин И.В.  Волгоград
# 3  Мельникова Д.С.     Ростов

# %%
frame[(frame.Birth > pd.datetime(1965,1,1))&(frame.City =='Москва')]
# Out:
#           Name      Birth    City  Position  IsStudent
# 0  Иванов А.А. 1980-03-22  Москва  Директор      False
# 4  Рыбина Е.П. 1985-11-19  Москва   инженер      False

# %%
frame
# Out:
#               Name      Birth       City  Position  IsStudent
# 0      Иванов А.А. 1980-03-22     Москва  Директор      False
# 1     Сорокин И.В. 1965-07-08  Волгоград   инженер      False
# 2       Белов М.М. 1980-02-13     Ростов  менеджер      False
# 3  Мельникова Д.С. 1985-04-15     Ростов  Директор      False
# 4      Рыбина Е.П. 1985-11-19     Москва   инженер      False

# %%
oTuple = (False, True, True, False, False)
frame['Test'] = oTuple
frame
# Out:
#               Name      Birth       City  Position  IsStudent   Test
# 0      Иванов А.А. 1980-03-22     Москва  Директор      False  False
# 1     Сорокин И.В. 1965-07-08  Волгоград   инженер      False   True
# 2       Белов М.М. 1980-02-13     Ростов  менеджер      False   True
# 3  Мельникова Д.С. 1985-04-15     Ростов  Директор      False  False
# 4      Рыбина Е.П. 1985-11-19     Москва   инженер      False  False

# %%
frame.addC
# Out:
#               Name      Birth       City  Position  IsStudent   Test
# 0      Иванов А.А. 1980-03-22     Москва  Директор      False   True
# 1     Сорокин И.В. 1965-07-08  Волгоград   инженер      False   True
# 2       Белов М.М. 1980-02-13     Ростов  менеджер      False   True
# 3  Мельникова Д.С. 1985-04-15     Ростов  Директор      False   True
# 4      Рыбина Е.П. 1985-11-19     Москва   инженер      False  False
