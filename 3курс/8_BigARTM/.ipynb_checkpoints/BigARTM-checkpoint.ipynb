# %% [markdown]
# # Пример использования библиотеки BigARTM для тематического моделирования
# ## Для Bigartm v0.8.0
# ### Редактировал Максим Чурилин

# %% [markdown]
# Импортируем BigARTM:

# %%
from matplotlib import pyplot as plt


import seaborn

seaborn.set_style("whitegrid", {'axes.grid' : False})

# %matplotlib inline

# %%
import artm

# %% [markdown]
# Первое считывание данных (преобразуем удобный для человека формат в формат, который использует модель):

# %%
batch_vectorizer = artm.BatchVectorizer(data_path="school.txt", data_format="vowpal_wabbit", target_folder="school_batches", 
                                       batch_size=100)

# %% [markdown]
# В следующий раз данные можно считывать уже из батчей:

# %%
batch_vectorizer = artm.BatchVectorizer(data_path="school_batches", data_format='batches')

# %% [markdown]
# Создаем объект модели:

# %%
T = 10   # количество тем
model_artm = artm.ARTM(num_topics=T, topic_names=["sbj"+str(i) for i in range(T)], class_ids={"text":1}, 
                       num_document_passes=1, reuse_theta=True, cache_theta=True, seed=-1)
# число после названия модальностей - это их веса

# %% [markdown]
# Создаем словарь и инициализируем модель с его помощью

# %%
dictionary = artm.Dictionary('dictionary')
dictionary.gather(batch_vectorizer.data_path)

# %%
model_artm.scores.add(artm.PerplexityScore(name='PerplexityScore',
                                           dictionary='dictionary'))
model_artm.scores.add(artm.SparsityPhiScore(name='SparsityPhiScore', class_id="text"))
model_artm.scores.add(artm.SparsityThetaScore(name='SparsityThetaScore'))
model_artm.scores.add(artm.TopTokensScore(name="top_words", num_tokens=15, class_id="text"))

# %%
model_artm.initialize('dictionary')

# %% [markdown]
# Строим модель. Offline - проходит по всей коллекции много раз. Удобно, когда коллекция маленькая.

# %%
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=30)

# %% [markdown]
# Необходимое число итераций можно отслеживать по графику перплексии. Когда она перестала меняться, модель сошлась.

# %%
plt.plot(model_artm.score_tracker["PerplexityScore"].value)

# %% [markdown]
# Выведем топы слов:

# %%
for topic_name in model_artm.topic_names:
    print topic_name + ': ',
    tokens = model_artm.score_tracker["top_words"].last_tokens
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# sbj0:  который быть что это человек этот как свой для они его весь такой себя время
# sbj1:  x a y b выражение квадрат многочлен множитель f олег разность скобка целый раскладывать сумма
# sbj2:  существительное падеж слово обособление куприн роман раскольников словосочетание мастер предложение маргарита любовь повесть подчинительный писатель
# sbj3:  который человек свой государство жизнь год что как быть становиться себя его страна время они
# sbj4:  x a b функция уравнение дробь f y квадратный корень решение точка c выражение преломление
# sbj5:  быть человек который свой его год жизнь что весь пушкин государство становиться время себя они
# sbj6:  быть это для этот который что такой как при сила мочь если один тело энергия
# sbj7:  человек который что свой общество герой себя являться лермонтов отношение она образ его представлять жизнь
# sbj8:  который быть что это свой как этот для человек они такой государство весь являться его
# sbj9:  быть что который этот это как для такой являться при мочь один сила так весь

# %% [markdown]
# Давайте посмотрим также на разреженность матриц:

# %%
print model_artm.score_tracker["SparsityPhiScore"].last_value
print model_artm.score_tracker["SparsityThetaScore"].last_value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-200-7f775fe13a51> in <module>()
# ----> 1 print model_artm.score_tracker["SparsityPhiScore"].last_value
#       2 print model_artm.score_tracker["SparsityThetaScore"].last_value
#
# KeyError: 'SparsityPhiScore'

# %% [markdown]
# В темах много общеупотребительных слов (так называемой, фоновой лексики). Чтобы этого избежать, будем использовать разреживающий регуляризатор для матрицы фи. Он будет подавлять слова, которые имеют большую частоту во всей коллекции.

# %%
model_artm.regularizers.add(artm.SmoothSparsePhiRegularizer(name='SparsePhi', tau=-100, dictionary=dictionary))
#если вы хотите применять регуляризатор только к некоторым модальностям, указывайте это в параметре class_ids: class_ids=["text"]

# %%
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=40)

# %%
plt.plot(model_artm.score_tracker["PerplexityScore"].value)

# %%
for topic_name in model_artm.topic_names:
    print topic_name + ': ',
    tokens = model_artm.score_tracker["top_words"].last_tokens
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# sbj0:  который что быть это человек этот как свой его герой для весь уравнение они такой
# sbj1:  x a b y также выражение квадрат многочлен получать сумма пример множитель разность ответ целый
# sbj2:  предложение писатель блок обособление слово куприн раскольников односоставный роман мастер словосочетание любовь рассказ гуманистический повесть
# sbj3:  который что свой человек как быть это этот они жизнь себя весь являться для государство
# sbj4:  x a функция уравнение дробь y f квадратный решение точка свет угол c измерение величина
# sbj5:  быть который что год его пушкин весь как этот это если человек они сила для
# sbj6:  год один быть при для тело энергия социальный например мочь если или который маленький лермонтов
# sbj7:  герой произведение рассказ литература литературный писатель автор предложение чувство читатель творчество повесть личность художественный стихотворение
# sbj8:  который быть что это свой как этот для человек они государство такой являться весь год
# sbj9:  быть при этот один число b это также что год энергия ток для магнитный или

# %%
print model_artm.score_tracker["SparsityPhiScore"].last_value
print model_artm.score_tracker["SparsityThetaScore"].last_value
# Out:
# 0.819988846779
# 0.125840336084

# %% [markdown]
# Попробуем менять коэффициент регуляризации:

# %%
model_artm.regularizers['SparsePhi'].tau = -3*1e3

# %%
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=40)

# %%
plt.plot(model_artm.score_tracker["PerplexityScore"].value)

# %%
for topic_name in model_artm.topic_names:
    print topic_name + ': ',
    tokens = model_artm.score_tracker["top_words"].last_tokens
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# sbj0:  который что быть это человек этот как свой его герой для весь уравнение они такой
# sbj1:  x a b y также выражение квадрат многочлен получать сумма пример множитель разность ответ целый
# sbj2:  предложение писатель блок обособление слово куприн раскольников односоставный роман мастер словосочетание любовь рассказ гуманистический повесть
# sbj3:  который что свой человек как быть это этот они жизнь себя весь являться для государство
# sbj4:  x a функция уравнение дробь y f квадратный решение точка свет угол c измерение величина
# sbj5:  быть который что год его пушкин весь как этот это если человек они сила для
# sbj6:  год один быть при для тело энергия социальный например мочь если или который маленький лермонтов
# sbj7:  герой произведение рассказ литература литературный писатель автор предложение чувство читатель творчество повесть личность художественный стихотворение
# sbj8:  который быть что это свой как этот для человек они государство такой являться весь год
# sbj9:  быть при этот один число b это также что год энергия ток для магнитный или

# %%
# еще раз посмотрим на разреженность
print model_artm.score_tracker["SparsityPhiScore"].last_value
print model_artm.score_tracker["SparsityThetaScore"].last_value
# Out:
# 0.819988846779
# 0.125840336084

# %% [markdown]
# Обратите внимание, что разреживать модель рекомендуется только после того, как она сошлась без регуляризации.

# %% [markdown]
# Сохранение и загрузка модели:

# %%
model_artm.save("my_model")

# %%
model_artm.load("my_model")

# %% [markdown]
# Можно попросить матрицы в чистом виде:

# %%
phi = model_artm.get_phi()

# %%
phi
# Out:
#                                       sbj0  sbj1      sbj2      sbj3  sbj4  \
# палеолит                          0.000000   0.0  0.000000  0.000000   0.0
# задабривать                       0.000000   0.0  0.000000  0.000000   0.0
# шаманский                         0.000000   0.0  0.000000  0.000000   0.0
# усопший                           0.000000   0.0  0.000000  0.000000   0.0
# рисование                         0.000000   0.0  0.000000  0.000000   0.0
# бивень                            0.000000   0.0  0.000000  0.000000   0.0
#
#                                       sbj5      sbj6      sbj7          sbj8  \
# домохозяйка                       0.000000  0.000000  0.000000  0.000000e+00
# институт                          0.000000  0.000023  0.000000  5.528726e-04
# машинка                           0.000046  0.000000  0.000000  0.000000e+00
# прочий                            0.000069  0.000206  0.000000  0.000000e+00
# навязнуть                         0.000061  0.000061  0.000000  0.000000e+00
# физиология                        0.000137  0.000000  0.000000  0.000000e+00
# истязать                          0.000000  0.000000  0.000000  2.740623e-05
# выборы                            0.000190  0.000000  0.000000  3.790784e-04
# кндр                              0.000000  0.000000  0.000000  0.000000e+00
# федерализм                        0.000000  0.000000  0.000000  2.740623e-05
# отсчитываться                     0.000000  0.000000  0.000000  5.481246e-05
# распространяться                  0.000000  0.000247  0.000000  0.000000e+00
# прикасаться                       0.000059  0.000000  0.000000  0.000000e+00
# батырь                            0.000000  0.000000  0.000000  0.000000e+00
# обществеОгромное                  0.000000  0.000000  0.000000  2.740623e-05
# бить                              0.000051  0.000083  0.000000  5.406618e-05
# отдалять                          0.000000  0.000094  0.000000  0.000000e+00
# речка                             0.000000  0.000094  0.000000  0.000000e+00
# неполноценность                   0.000000  0.000000  0.000000  2.740623e-05
# невозможенУже                     0.000000  0.000000  0.000156  1.926829e-09
# развивающийся                     0.000073  0.000000  0.000083  0.000000e+00
# теплопроводностиТеплопроводность  0.000000  0.000092  0.000000  0.000000e+00
# заповедник                        0.000000  0.000182  0.000000  2.817625e-05
# преувеличиваться                  0.000000  0.000000  0.000000  0.000000e+00
# межнациональный                   0.000000  0.001160  0.000000  3.908025e-05
# протест                           0.000336  0.000000  0.000000  6.572724e-05
# виднеться                         0.000000  0.000000  0.000000  0.000000e+00
# основа                            0.000000  0.000015  0.000000  6.760223e-04
# преграда                          0.000000  0.000000  0.000000  3.789586e-05
# топливо                           0.000000  0.000000  0.000000  1.091417e-04
# ...                                    ...       ...       ...           ...
# обывательщина                     0.000000  0.000000  0.000000  0.000000e+00
# настрой                           0.000000  0.000000  0.000000  0.000000e+00
# нелегкий                          0.000000  0.000000  0.000000  0.000000e+00
# рассказеГранатовый                0.000000  0.000000  0.000000  0.000000e+00
# простираться                      0.000000  0.000000  0.000000  0.000000e+00
# Маншского                         0.000000  0.000000  0.000000  0.000000e+00
# колонизаторский                   0.000000  0.000000  0.000000  0.000000e+00
# пикардия                          0.000000  0.000000  0.000000  0.000000e+00
# нормандия                         0.000000  0.000000  0.000000  0.000000e+00
# Пуату                             0.000000  0.000000  0.000000  0.000000e+00
# Шаранта                           0.000000  0.000000  0.000000  0.000000e+00
# овернь                            0.000000  0.000000  0.000000  0.000000e+00
# пиренеи                           0.000000  0.000000  0.000000  0.000000e+00
# прованс                           0.000000  0.000000  0.000000  0.000000e+00
# корсик                            0.000000  0.000000  0.000000  0.000000e+00
# лазурный                          0.000000  0.000000  0.000000  0.000000e+00
# савойя                            0.000000  0.000000  0.000000  0.000000e+00
# монблан                           0.000000  0.000000  0.000000  0.000000e+00
# гарон                             0.000000  0.000000  0.000000  0.000000e+00
# аист                              0.000000  0.000000  0.000000  0.000000e+00
# корсиканский                      0.000000  0.000000  0.000000  0.000000e+00
# серна                             0.000000  0.000000  0.000000  0.000000e+00
# вплетать                          0.000046  0.000000  0.000000  0.000000e+00
# Homo                              0.000046  0.000000  0.000000  0.000000e+00
# палеолит                          0.000046  0.000000  0.000000  0.000000e+00
# задабривать                       0.000046  0.000000  0.000000  0.000000e+00
# шаманский                         0.000046  0.000000  0.000000  0.000000e+00
# усопший                           0.000046  0.000000  0.000000  0.000000e+00
# рисование                         0.000046  0.000000  0.000000  0.000000e+00
# бивень                            0.000046  0.000000  0.000000  0.000000e+00
#
#                                       sbj9
# домохозяйка                       0.000000
# институт                          0.000000
# машинка                           0.000000
# прочий                            0.000295
# навязнуть                         0.000000
# физиология                        0.000000
# истязать                          0.000000
# выборы                            0.000000
# кндр                              0.000000
# федерализм                        0.000000
# отсчитываться                     0.000000
# распространяться                  0.000000
# прикасаться                       0.000000
# батырь                            0.000000
# обществеОгромное                  0.000000
# бить                              0.000000
# отдалять                          0.000000
# речка                             0.000000
# неполноценность                   0.000000
# невозможенУже                     0.000000
# развивающийся                     0.000000
# теплопроводностиТеплопроводность  0.000000
# заповедник                        0.000000
# преувеличиваться                  0.000000
# межнациональный                   0.000000
# протест                           0.000000
# виднеться                         0.000000
# основа                            0.000000
# преграда                          0.000000
# топливо                           0.003065
# ...                                    ...
# обывательщина                     0.000000
# настрой                           0.000000
# нелегкий                          0.000000
# рассказеГранатовый                0.000000
# простираться                      0.000000
# Маншского                         0.000000
# колонизаторский                   0.000000
# пикардия                          0.000000
# нормандия                         0.000000
# Пуату                             0.000000
# Шаранта                           0.000000
# овернь                            0.000000
# пиренеи                           0.000000
# прованс                           0.000000
# корсик                            0.000000
# лазурный                          0.000000
# савойя                            0.000000
# монблан                           0.000000
# гарон                             0.000000
# аист                              0.000000
# корсиканский                      0.000000
# серна                             0.000000
# вплетать                          0.000000
# Homo                              0.000000
# палеолит                          0.000000
# задабривать                       0.000000
# шаманский                         0.000000
# усопший                           0.000000
# рисование                         0.000000
# бивень                            0.000000
#
# [16099 rows x 10 columns]

# %% [markdown]
# Матрица вероятностей тем в документах.

# %%
theta = model_artm.get_theta()
theta
# Out:
#                100           101           102           103           104  \
# sbj0  1.450775e-03  1.097158e-03  1.558186e-03  1.246090e-03  1.522960e-03
# sbj1  2.026586e-02  8.786250e-03  9.968620e-03  8.160087e-03  1.035378e-03
# sbj2  2.837760e-07  4.174064e-08  3.093888e-07  5.281191e-08  9.729217e-07
# sbj3  6.729579e-01  7.615246e-01  4.989893e-01  6.939589e-01  5.669090e-01
# sbj4  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# sbj5  6.916406e-02  2.553391e-02  4.136004e-02  1.911213e-02  5.154831e-02
# sbj6  1.312366e-01  1.677282e-01  3.090309e-01  2.387521e-01  3.165556e-01
# sbj7  8.116617e-02  5.962539e-03  1.191498e-01  7.782281e-03  3.560376e-02
# sbj8  2.375831e-02  2.936732e-02  1.994291e-02  3.098838e-02  2.682411e-02
# sbj9  9.187495e-13  5.794360e-12  1.977780e-12  3.630636e-12  2.124918e-12
